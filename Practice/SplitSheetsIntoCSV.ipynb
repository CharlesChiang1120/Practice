# %%
import pandas as pd

# %%
from collections import OrderedDict

# %%
sheet1 = pd.read_excel('/Users/charles/Desktop/split_test.xls',sheet_name = ['sheet1'])

# %%
sheet1
# Out:
# OrderedDict([('sheet1',
#                   First Name Last Name                Company Name                 Address  \
#               0     Rebbecca     Didio      Brandt, Jonathan F Esq           171 E 24th St
#               1       Stevie     Hallo  Landrum Temporary Services          22222 Acoma St
#               2       Mariko    Stayer         Inabinet, Macre Esq   534 Schoenborn St #51
#               3      Gerardo    Woodka    Morris Downing & Sherred       69206 Jackson Ave
#               4        Mayra      Bena          Buelt, David L Esq       808 Glen Cove Ave
#               ..         ...       ...                         ...                     ...
#               495      Miles   Feldner   Antietam Cable Television  28465 Downey Ave #4238
#               496      Julio     Mikel           Lombardi Bros Inc     2803 N Catalina Ave
#               497       Aide     Ghera       Nathaniel Electronics       22 Livingston Ave
# ...

# %%
sheet1 = pd.concat(sheet1[frame] for frame in sheet1.keys())

# %%
sheet1
# Out:
#     First Name Last Name                Company Name                 Address  \
# 0     Rebbecca     Didio      Brandt, Jonathan F Esq           171 E 24th St
# 1       Stevie     Hallo  Landrum Temporary Services          22222 Acoma St
# 2       Mariko    Stayer         Inabinet, Macre Esq   534 Schoenborn St #51
# 3      Gerardo    Woodka    Morris Downing & Sherred       69206 Jackson Ave
# 4        Mayra      Bena          Buelt, David L Esq       808 Glen Cove Ave
# ..         ...       ...                         ...                     ...
# 495      Miles   Feldner   Antietam Cable Television  28465 Downey Ave #4238
# 496      Julio     Mikel           Lombardi Bros Inc     2803 N Catalina Ave
# 497       Aide     Ghera       Nathaniel Electronics       22 Livingston Ave
# 498     Noelia  Brackett     Rodriguez, Joseph A Esq      403 Conn Valley Rd
# 499     Lenora  Delacruz     Stilling, William J Esq          5400 Market St
#
# ...

# %%
sheet1.to_csv("/Users/charles/Desktop/sheet1_output.csv", index=False)

# %%
sheet2 = pd.read_excel('/Users/charles/Desktop/split_test.xls',sheet_name = ['sheet2'])

# %%
sheet2
# Out:
# OrderedDict([('sheet2',       Category      Product    Sales Quarter
#               0    Beverages         Chai   705.60   Qtr 1
#               1    Beverages         Chai   878.40   Qtr 2
#               2    Beverages         Chai  1174.50   Qtr 3
#               3    Beverages         Chai  2128.50   Qtr 4
#               4    Beverages        Chang  2720.80   Qtr 1
#               ..         ...          ...      ...     ...
#               281    Seafood  Røgede sild  1953.67   Qtr 4
#               282    Seafood    Spegesild   803.52   Qtr 1
#               283    Seafood    Spegesild    91.80   Qtr 2
#               284    Seafood    Spegesild  1504.80   Qtr 3
#               285    Seafood    Spegesild   823.20   Qtr 4
#
#               [286 rows x 4 columns])])

# %%
sheet2 = pd.concat(sheet2[frame] for frame in sheet2.keys())

# %%
sheet2
# Out:
#       Category      Product    Sales Quarter
# 0    Beverages         Chai   705.60   Qtr 1
# 1    Beverages         Chai   878.40   Qtr 2
# 2    Beverages         Chai  1174.50   Qtr 3
# 3    Beverages         Chai  2128.50   Qtr 4
# 4    Beverages        Chang  2720.80   Qtr 1
# ..         ...          ...      ...     ...
# 281    Seafood  Røgede sild  1953.67   Qtr 4
# 282    Seafood    Spegesild   803.52   Qtr 1
# 283    Seafood    Spegesild    91.80   Qtr 2
# 284    Seafood    Spegesild  1504.80   Qtr 3
# 285    Seafood    Spegesild   823.20   Qtr 4
#
# [286 rows x 4 columns]

# %%
sheet2.to_csv("/Users/charles/Desktop/sheet2_output.csv", index=False)
